# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=1000, n_features=1, random_state=0, noise=30)

plt.scatter(X,y, s=3)
plt.show()

# %%
class LinearRegression():
    def __init__(self, m, n_x):
        theta = np.zeros(n_x)
        print(m, n_x)
    
    def fit(X, y):

# %%
m = len(y)
n_x = 2

reg = LinearRegression(m, n_x)
# Out:
# 1000 2
# 1000 2
